# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("student_performance_prediction.csv")

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.isnull().sum()
# Out:
# Student ID                                        0
# Study Hours per Week                           1995
# Attendance Rate                                1992
# Previous Grades                                1994
# Participation in Extracurricular Activities    2000
# Parent Education Level                         2000
# Passed                                         2000
# dtype: int64

# %%
print("Shape before:", df.shape)
# Out:
# Shape before: (40000, 7)

# %%
df.dropna(inplace=True)

# %%
print("Shape after:", df.shape)
# Out:
# Shape after: (29446, 7)

# %%
lb = LabelEncoder()
for col in df.select_dtypes(include=['object']).columns:
    df[col] = lb.fit_transform(df[col])
    
df.head()
# Out:
#    Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 1           0                   9.3             95.3             60.6
# 3           1                  17.6             76.8             62.4
# 4           2                   8.8             89.3             72.7
# 5           3                   8.8             73.8             69.3
# 6           4                  17.9             38.6             93.6
#
#    Participation in Extracurricular Activities  Parent Education Level  Passed
# 1                                            0                       3       0
# 3                                            1                       1       0
# 4                                            0                       4       0
# 5                                            1                       3       1
# 6                                            0                       2       1

# %%
print(df.columns)
# Out:
# Index(['Student ID', 'Study Hours per Week', 'Attendance Rate',
#        'Previous Grades', 'Participation in Extracurricular Activities',
#        'Parent Education Level', 'Passed'],
#       dtype='object')

# %%
target = 'Passed'
X = df.drop([target, 'Student ID'], axis=1)
y = df[target]

# %%
from sklearn.preprocessing import LabelEncoder , StandardScaler
lb = LabelEncoder()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# 1. This line is the magic that officially defines 'df'
df = pd.read_csv("student_performance_prediction.csv")

# Drop any missing rows to keep it clean
df.dropna(inplace=True)

# 2. This line officially defines 'lb' so you can use it below
lb = LabelEncoder()

print("Success! df and lb are now loaded into memory.")
# Out:
# Success! df and lb are now loaded into memory.

# %%
df['Attendance Rate'] = lb.fit_transform(df['Attendance Rate'])
df['Student ID'] = lb.fit_transform(df['Student ID'])

# %%
x = df.drop('Parent Education Level' , axis = 1)
y = df['Parent Education Level']

# %%
sc = StandardScaler()

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

print("Success! All text was converted to numbers and scaling is complete.")
# Out:
# Success! All text was converted to numbers and scaling is complete.

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split( X_scaled , y , test_size = 0.2 , random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. Initialize the scaler
scaler = StandardScaler()

# 2. FIT the scaler to your training data
X_train_scaled = scaler.fit_transform(X_train) 

# --- NEW CODE TO ADD ---
# Initialize the KNN classifier (you can change n_neighbors to your preferred value)
knn_model = KNeighborsClassifier(n_neighbors=5)
# -----------------------

# 3. Train your model on the scaled data
knn_model.fit(X_train_scaled, y_train)

# 4. SAVE the scaler AFTER it has been fitted
with open('scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

# 5. Save the model
with open('knn_model.pkl', 'wb') as model_file:
    pickle.dump(knn_model, model_file)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=7)

# %%
clf.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
clf.score(X_test , y_test)
# Out:
# 0.9971137521222411

# %%
pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test , pred))
# Out:
#               precision    recall  f1-score   support
#
#    Associate       1.00      1.00      1.00      1202
#     Bachelor       0.99      1.00      1.00      1149
#    Doctorate       1.00      0.99      1.00      1194
#  High School       1.00      1.00      1.00      1178
#       Master       1.00      1.00      1.00      1167
#
#     accuracy                           1.00      5890
#    macro avg       1.00      1.00      1.00      5890
# weighted avg       1.00      1.00      1.00      5890

# %%
import pickle
from sklearn.preprocessing import StandardScaler

# 1. Initialize the scaler
scaler = StandardScaler()

# 2. FIT the scaler to your training data (This calculates mean_ and scale_)
X_train_scaled = scaler.fit_transform(X_train) 

# 3. Train your model on the scaled data
knn_model.fit(X_train_scaled, y_train)

# 4. SAVE the scaler AFTER it has been fitted
with open('scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

# 5. Save the model
with open('knn_model.pkl', 'wb') as model_file:
    pickle.dump(knn_model, model_file)
